# %% [markdown]
# Importing Libriaries and Loading API DataFrame

# %%
import requests
import json
import pandas as pd
import geopandas as gpd


api_url = pd.DataFrame({
    'API_URL': [
        'https://maps2.bristol.gov.uk/server2/rest/services/ext/air_quality/MapServer/0/query?outFields=*&where=1%3D1&f=geojson'
    ]
})

# Reading the API

for i in api_url['API_URL']:
    response = requests.get(i)
    if response.status_code == 200:
        print(f"Source Data from Bristol.go.uk Website {i}:")
        print(response.json())
    else:
        print(f"Failed to fetch from {i}")
# Out:
# Source Data from Bristol.go.uk Website https://maps2.bristol.gov.uk/server2/rest/services/ext/air_quality/MapServer/0/query?outFields=*&where=1%3D1&f=geojson:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'id': 1, 'geometry': {'type': 'Point', 'coordinates': [-2.6277488032062446, 51.407745517999835]}, 'properties': {'OBJECTID': 1, 'siteNo': '1', 'location': 'Withywood School', 'SiteID': 1, 'Easting': 356434, 'Northing': 167823, 'Current_': 'No', 'pollutants': 'BTX NO2', 'InstrumentID': 1, 'Exposure': 'No', 'tube_kerb': 0, 'rec_kerb': 0, 'comments': '', 'AQMA': 'Yes', 'Detailed_Location': '', 'Tube_Height': None, 'Elevation': None, 'Grid_ID': None, 'LocationClass': 'Urban Traffic', 'LAQM_Locationclass': 'Roadside', 'Survey': 'Other (DT)', 'RouteID': None, 'RouteSequenceID': None, 'Description': '', 'DateStart': None, 'DateEnd': None, 'Colocated': None, 'Duplicate_Triplicate': '', 'obstruction_m': None, 'obstruction_lt': 'No', 'inlet_flow_clear': 'No', 'junction_m': None}}, {'type': 'Feature', 'id': 2, 'geometry': {'type': 'Point', 'coordinates': [-2.5968139474821794, 51.454556566902696]}, 'properties': {'OBJECTID': 2, 'siteNo': 'B1', 'location': 'Colston Avenue', 'SiteID': 2, 'Easting': 358628, 'Northing': 173011, 'Current_': 'Yes', 'pollutants': 'NO2', 'InstrumentID': 1, 'Exposure': 'No', 'tube_kerb': 1, 'rec_kerb': 1, 'comments': '', 'AQMA': 'Yes', 'Detailed_Location': 'on traffic light pedestrian crossing near statue of edmund burke', 'Tube_Height': 2.8, 'Elevation': 9.5, 'Grid_ID': 56, 'LocationClass': 'Urban Traffic', 'LAQM_Locationclass': 'Roadside', 'Survey': 'Roadside (DT)', 'RouteID': None, 'RouteSequenceID': None, 'Description': '', 'DateStart': None, 'DateEnd': None, 'Colocated': None, 'Duplicate_Triplicate': '', 'obstruction_m': 2, 'obstruction_lt': 'No', 'inlet_flow_clear': 'Yes', 'junction_m': 1}}, {'type': 'Feature', 'id': 3, 'geometry': {'type': 'Point', 'coordinates': [-2.613994167991525, 51.46920548941127]}, 'properties': {'OBJECTID': 3, 'siteNo': 'B10', 'location': 'Blackboy Hill', 'SiteID': 3, 'Easting': 357448, 'Northing': 174650, 'Current_': 'Yes', 'pollutants': 'NO2', 'InstrumentID': 1, 'Exposure': 'Yes', 'tube_kerb': 3, 'rec_kerb': 3, 'comments': '', 'AQMA': 'No', 'Detailed_Location': 'lamppost façade domus pizza', 'Tube_Height': 2.8, 'Elevation': 79.2, 'Grid_ID': 65, 'LocationClass': 'Urban Traffic', 'LAQM_Locationclass': 'Roadside', 'Survey': 'Roadside (DT)', 'RouteID': None, 'RouteSequenceID': None, 'Description': '', 'DateStart': None, 'DateEnd': None, 'Colocated': None, 'Duplicate_Triplicate': '', 'obstruction_m': 1, 'obstruction_lt': 'Yes', 'inlet_flow_clear': 'No', 'junction_m': 32}}, {'type': 'Feature', 'id': 4, 'geometry': {'type': 'Point', 'coordinates': [-2.578333463205696, 51.444209895530584]}, 'properties': {'OBJECTID': 4, 'siteNo': 'B11', 'location': 'Three Lamps', 'SiteID': 4, 'Easting': 359903, 'Northing': 171850, 'Current_': 'Yes', 'pollutants': 'NO2', 'InstrumentID': 1, 'Exposure': 'No', 'tube_kerb': 3, 'rec_kerb': 3, 'comments': '', 'AQMA': 'Yes', 'Detailed_Location': 'On lamp post on the on the Bath Road side of the landscaped triangle in the middle of the Three Lamps junction. ', 'Tube_Height': 3.2, 'Elevation': 26.6, 'Grid_ID': 41, 'LocationClass': 'Urban Traffic', 'LAQM_Locationclass': 'Roadside', 'Survey': 'Roadside (DT)', 'RouteID': None, 'RouteSequenceID': None, 'Description': '', 'DateStart': None, 'DateEnd': None, 'Colocated': None, 'Duplicate_Triplicate': '', 'obstruction_m': 4, 'obstruction_lt': 'No', 'inlet_flow_clear': 'Yes', 'junction_m': 1}}, {'type': 'Feature', 'id': 5, 'geometry': {'type': 'Point', 'coordinates': [-2.595294420664777, 51.442812042759506]}, 'properties': {'OBJECTID': 5, 'siteNo': 'B12', 'location': 'Bedminster Parade', 'SiteID': 5, 'Easting': 358723, 'Northing': 171704, 'Current_': 'Yes', 'pollutants': 'NO2', 'InstrumentID': 1, 'Exposure': 'Yes', 'tube_kerb': 1, 'rec_kerb': 1, 'comments': '', 'AQMA': 'Yes', 'Detailed_Location': 'under clock on side of colonade  overhanging street  on lamp post', 'Tube_Height': 3.2, 'Elevation': 8.1, 'Grid_ID': 40, 'LocationClass': 'Urban Traffic', 'LAQM_Locati ...

# %%
if response.status_code == 200:
    print("API load successful. Status code:", response.status_code)
else:
    print("API load failed. Status code:", response.status_code)
# Out:
# API load successful. Status code: 200

# %% [markdown]
# defining my dataframe

# %%
dataframe_df = api_url

# %% [markdown]
# saving dataframe im my folder to allow transformation

# %%
dataframe_df.to_csv("C:/Users/aldom/Documents/Data_Enginnering/Final_ETL_Portfolio_Submission/dataframe_df.csv", index=False)

# %% [markdown]
# With this step I am using a try and error technique using the most common encoding types to allow the next stages of the transformation

# %%
with open("C:/Users/aldom/Documents/Data_Enginnering/Final_ETL_Portfolio_Submission/api_data.geojson", encoding="ISO-8859-1") as f:
    content = f.read()
    print(content)
# Out:
# {
# "type": "FeatureCollection",
# "name": "api_data",
# "crs": { "type": "name", "properties": { "name": "urn:ogc:def:crs:OGC:1.3:CRS84" } },
# "features": [
# { "type": "Feature", "properties": { "OBJECTID": 1, "siteNo": "1", "location": "Withywood School", "SiteID": 1, "Easting": 356434, "Northing": 167823, "Current_": "No", "pollutants": "BTX NO2", "InstrumentID": 1, "Exposure": "No", "tube_kerb": 0.0, "rec_kerb": 0.0, "comments": "", "AQMA": "Yes", "Detailed_Location": "", "Tube_Height": null, "Elevation": null, "Grid_ID": null, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Other (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": null, "obstruction_lt": "No", "inlet_flow_clear": "No", "junction_m": null, "x": -2.627748803206245, "y": 51.407745517999835, "x_normalized": 0.45076298550013316, "y_normalized": 0.090933038267678512 }, "geometry": { "type": "Point", "coordinates": [ -2.627748803206245, 51.407745517999835 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 2, "siteNo": "B1", "location": "Colston Avenue", "SiteID": 2, "Easting": 358628, "Northing": 173011, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "No", "tube_kerb": 1.0, "rec_kerb": 1.0, "comments": "", "AQMA": "Yes", "Detailed_Location": "on traffic light pedestrian crossing near statue of edmund burke", "Tube_Height": 2.8, "Elevation": 9.5, "Grid_ID": 56.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": 2.0, "obstruction_lt": "No", "inlet_flow_clear": "Yes", "junction_m": 1.0, "x": -2.596813947482179, "y": 51.454556566902696, "x_normalized": 0.51587271716764338, "y_normalized": 0.29381591279840791 }, "geometry": { "type": "Point", "coordinates": [ -2.596813947482179, 51.454556566902696 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 3, "siteNo": "B10", "location": "Blackboy Hill", "SiteID": 3, "Easting": 357448, "Northing": 174650, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "Yes", "tube_kerb": 3.0, "rec_kerb": 3.0, "comments": "", "AQMA": "No", "Detailed_Location": "lamppost faÃÂ§ade domus pizza", "Tube_Height": 2.8, "Elevation": 79.2, "Grid_ID": 65.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": 1.0, "obstruction_lt": "Yes", "inlet_flow_clear": "No", "junction_m": 32.0, "x": -2.6139941679915251, "y": 51.469205489411273, "x_normalized": 0.479712873484198, "y_normalized": 0.35730552854030861 }, "geometry": { "type": "Point", "coordinates": [ -2.613994167991525, 51.469205489411273 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 4, "siteNo": "B11", "location": "Three Lamps", "SiteID": 4, "Easting": 359903, "Northing": 171850, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "No", "tube_kerb": 3.0, "rec_kerb": 3.0, "comments": "", "AQMA": "Yes", "Detailed_Location": "On lamp post on the on the Bath Road side of the landscaped triangle in the middle of the Three Lamps junction. ", "Tube_Height": 3.2, "Elevation": 26.6, "Grid_ID": 41.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": 4.0, "obstruction_lt": "No", "inlet_flow_clear": "Yes", "junction_m": 1.0, "x": -2.5783334632056958, "y": 51.444209895530584, "x_normalized": 0.55476927395330744, "y_normalized": 0.24897260167853119 }, "geometry": { "type": "Point", "coordinates": [ -2.578333463205696, 51.444209895530584 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 5, "siteNo": "B12", "location": "Bedminster Parade", "SiteID": 5, "Easting": 358723, "Northing": 171704, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "Yes", "tube_kerb": 1.0, "rec_kerb": 1.0, "comments": "", "AQMA": "Yes", "Detailed_Location": "under clock on side of colonade  overhanging street  on lamp post", "Tube_Height": 3.2, "Elevation": 8.1, "Grid_ID": 40.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": 1.0, "obstruction_lt": "Yes", "inlet_flow_clear": "No", "junction_m": 96.0, "x": -2.5952944206647768, "y": 51.442812042759506, "x_normalized": 0.51907092129780441, "y_normalized": 0.24291419463546049 }, "geometry": { "type": "Point", "coordinates": [ -2.595294420664777, 51.442812042759506 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 6, "siteNo": "B13", "location": "Church Road", "SiteID": 6, "Easting": 361261, "Northing": 173413, "Current_": "No", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "Yes", "tube_kerb": 3.0, "rec_kerb": 3.0, "comments": "", "AQMA": "Yes", "Detailed_Location": "On road sign on junction of Byron Road and Church Road  immediately adjacent to Premiere Phones retail unit. Parking on site.", "Tube_Height": 2.3, "Elevation": 23.6, "Grid_ID": 59.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": null, "obstruction_lt": "No", "inlet_flow_clear": "No", "junction_m": null, "x": -2.5589652892479742, "y": 51.458358093425005, "x_normalized": 0.59553418394756541, "y_normalized": 0.31029203641725189 }, "geometry": { "type": "Point", "coordinates": [ -2.558965289247974, 51.458358093425005 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 7, "siteNo": "B14", "location": "St. Andrew's Rd", "SiteID": 7, "Easting": 351706, "Northing": 178250, "Current_": "No", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "No", "tube_kerb": 3.0, "rec_kerb": 6.0, "comments": "", "AQMA": "No", "Detailed_Location": "lamppost 6 outside number 38 st. andrews road", "Tube_Height": 2.6, "Elevation": 6.8, "Grid_ID": 115.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": null, "obstruction_lt": "No", "inlet_flow_clear": "No", "junction_m": null, "x": -2.697147645214006, "y": 51.501109819550628, "x_normalized": 0.30469668341468381, "y_normalized": 0.49558147749590375 }, "geometry": { "type": "Point", "coordinates": [ -2.697147645214006, 51.501109819550628 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 8, "siteNo": "B15", "location": "Higham Street", "SiteID": 8, "Easting": 359836, "Northing": 171903, "Current_": "No", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "Yes", "tube_kerb": null, "rec_kerb": null, "comments": "To main Wells Rd. <1 to local kerb", "AQMA": "Yes", "Detailed_Location": "On lamp post on edge of park  on opposite side of the road from No. 5 Higham Street. Parking on site.", "Tube_Height": 2.8, "Elevation": 35.8, "Grid_ID": 41.0, "LocationClass": "Urban Background", "LAQM_Locationclass": "Urban background", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": null, "obstruction_lt": "No", "inlet_flow_clear": "No", "junction_m": null, "x": -2.5793034868605589, "y": 51.444681659520448, "x_normalized": 0.55272762939408793, "y_normalized": 0.25101726499215715 }, "geometry": { "type": "Point", "coordinates": [ -2.579303486860559, 51.444681659520448 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 9, "siteNo": "B16", "location": "B.R.I.", "SiteID": 9, "Easting": 358729, "Northing": 173499, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "Yes", "tube_kerb": 1.0, "rec_kerb": 1.0, "comments": "", "AQMA": "Yes", "Detailed_Location": "on traffic light pole pedestrian crossing opposite BRI junction with lower maudlin street", "Tube_Height": 2.4, "Elevation": 19.9, "Grid_ID": 56.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": 1.0, "obstruction_lt": "No", "inlet_flow_clear": "Yes", "junction_m": 15.0, "x": -2.5954175081992821, "y": 51.458951763763132, "x_normalized": 0.51881185442467093, "y_normalized": 0.31286505171055978 }, "geometry": { "type": "Point", "coordinates": [ -2.595417508199282, 51.458951763763132 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 10, "siteNo": "B17", "location": "Bath Road", "SiteID": 10, "Easting": 361217, "Northing": 171429, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "Yes", "tube_kerb": 4.0, "rec_kerb": 9.0, "comments": "comments", "AQMA": "Yes", "Detailed_Location": "On back of a no right turn sign on the left side of the Bath Road on the way up the hill outside No 453. No parking at site - park in Brislington Dep", "Tube_Height": 3.2, "Elevation": 20.3, "Grid_ID": 43.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": 3.0, "obstruction_lt": "No", "inlet_flow_clear": "Yes", "junction_m": 150.0, "x": -2.559380932414363, "y": 51.440516404879745, "x_normalized": 0.59465936444705125, "y_normalized": 0.23296471427036636 }, "geometry": { "type": "Point", "coordinates": [ -2.559380932414363, 51.440516404879745 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 11, "siteNo": "B18", "location": "Whitefriars", "SiteID": 11, "Easting": 358813, "Northing": 173342, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "No", "tube_kerb": 5.0, "rec_kerb": 5.0, "comments": "Commercial property", "AQMA": "Yes", "Detailed_Location": "opposite whitefriars in carpark adjacent evans cycles", "Tube_Height": 3.2, "Elevation": 8.5, "Grid_ID": 56.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": 1.0, "obstruction_lt": "Yes", "inlet_flow_clear": "No", "junction_m": 109.0, "x": -2.5941901851545559, "y": 51.45754626447907, "x_normalized": 0.5213950464985011, "y_normalized": 0.30677350406133996 }, "geometry": { "type": "Point", "coordinates": [ -2.594190185154556, 51.45754626447907 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 12, "siteNo": "B19", "location": "Galleries", "SiteID": 12, "Easting": 359142, "Northing": 173211, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "No", "tube_kerb": 1.0, "rec_kerb": 100.0, "comments": "", "AQMA": "Yes", "Detailed_Location": "on one way sign opposite police towaway sign", "Tube_Height": 2.4, "Elevation": 12.5, "Grid_ID": 57.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": 1.0, "obstruction_lt": "No", "inlet_flow_clear": "Yes", "junction_m": 73.0, "x": -2.589439954461159, "y": 51.45639234685148, "x_normalized": 0.53139303221935297, "y_normalized": 0.30177233167268014 }, "geometry": { "type": "Point", "coordinates": [ -2.589439954461159, 51.45639234685148 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 13, "siteNo": "B2", "location": "Ferndown Close", "SiteID": 13, "Easting": 354493, "Northing": 177489, "Current_": "No", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "Yes", "tube_kerb": null, "rec_kerb": null, "comments": "", "AQMA": "No", "Detailed_Location": "lamppost 6", "Tube_Height": 2.3, "Elevation": 69.1, "Grid_ID": 103.0, "LocationClass": "Urban Background", "LAQM_Locationclass": "Urban background", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": null, "obstruction_lt": "No", "inlet_flow_clear": "No", "junction_m": null, "x": -2.656900421884163, "y": 51.494500011999612, "x_normalized": 0.3894064986064123, "y_normalized": 0.46693403661441835 }, "geometry": { "type": "Point", "coordinates": [ -2.656900421884163, 51.494500011999612 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 14, "siteNo": "B20", "location": "Red Lion Knowle", "SiteID": 14, "Easting": 360877, "Northing": 170280, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "Yes", "tube_kerb": 2.0, "rec_kerb": 8.0, "comments": "", "AQMA": "Yes", "Detailed_Location": "Outside the Imperial Guest House on telegraph pole.  Pull up at site for short period of time as no official parking and road busy.", "Tube_Height": 2.4, "Elevation": 60.6, "Grid_ID": 32.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": 3.0, "obstruction_lt": "No", "inlet_flow_clear": "Yes", "junction_m": 267.0, "x": -2.5641445698086751, "y": 51.430162172230453, "x_normalized": 0.58463316114836594, "y_normalized": 0.18808863196323955 }, "geometry": { "type": "Point", "coordinates": [ -2.564144569808675, 51.430162172230453 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 15, "siteNo": "B21", "location": "Horsefair", "SiteID": 15, "Easting": 359294, "Northing": 173485, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "No", "tube_kerb": 2.0, "rec_kerb": 5.0, "comments": "", "AQMA": "Yes", "Detailed_Location": "Lamppost outside macdonalds near cabot circus entrance", "Tube_Height": 2.2, "Elevation": 10.3, "Grid_ID": 57.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": 1.0, "obstruction_lt": "No", "inlet_flow_clear": "Yes", "junction_m": 160.0, "x": -2.58728394597538, "y": 51.4588669853932, "x_normalized": 0.53593086278931246, "y_normalized": 0.3124976153938519 }, "geometry": { "type": "Point", "coordinates": [ -2.58728394597538, 51.4588669853932 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 16, "siteNo": "B3", "location": "Third Way", "SiteID": 16, "Easting": 352287, "Northing": 178698, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "No", "tube_kerb": 2.0, "rec_kerb": 100.0, "comments": "", "AQMA": "No", "Detailed_Location": "lamppost 16 anglian windows", "Tube_Height": 2.7, "Elevation": 7.6, "Grid_ID": 116.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": 2.0, "obstruction_lt": "No", "inlet_flow_clear": "Yes", "junction_m": 315.0, "x": -2.6888390135577191, "y": 51.505187159006432, "x_normalized": 0.32218416686992946, "y_normalized": 0.51325299669102264 }, "geometry": { "type": "Point", "coordinates": [ -2.688839013557719, 51.505187159006432 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 17, "siteNo": "B4", "location": "Anglesea Place", "SiteID": 17, "Easting": 357273, "Northing": 174582, "Current_": "No", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "No", "tube_kerb": 1.0, "rec_kerb": 6.0, "comments": "To School building behind wall", "AQMA": "No", "Detailed_Location": "lamppost achool sign", "Tube_Height": 2.8, "Elevation": 81.2, "Grid_ID": 65.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": null, "obstruction_lt": "No", "inlet_flow_clear": "No", "junction_m": null, "x": -2.616505262752693, "y": 51.468580852794794, "x_normalized": 0.47442767973544697, "y_normalized": 0.35459830289042316 }, "geometry": { "type": "Point", "coordinates": [ -2.616505262752693, 51.468580852794794 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 18, "siteNo": "B5", "location": "Hillcrest", "SiteID": 18, "Easting": 360691, "Northing": 170081, "Current_": "No", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "Yes", "tube_kerb": null, "rec_kerb": null, "comments": "", "AQMA": "No", "Detailed_Location": "Outside No. 16 on telegraph pole on corner of junction between Hillcrest and narrow back lane to rear garden area. Parking at site.", "Tube_Height": 3.2, "Elevation": 54.1, "Grid_ID": 32.0, "LocationClass": "Urban Background", "LAQM_Locationclass": "Urban background", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": null, "obstruction_lt": "No", "inlet_flow_clear": "No", "junction_m": null, "x": -2.5667976031020698, "y": 51.428360058828844, "x_normalized": 0.57904922413638538, "y_normalized": 0.18027812662916176 }, "geometry": { "type": "Point", "coordinates": [ -2.56679760310207, 51.428360058828844 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 19, "siteNo": "B6", "location": "Conham Vale", "SiteID": 19, "Easting": 362921, "Northing": 172122, "Current_": "No", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "No", "tube_kerb": 1.0, "rec_kerb": 100.0, "comments": "", "AQMA": "No", "Detailed_Location": "On 5 T road sign at entrance to car park (in bracket holding sign).  Parking in car park. ", "Tube_Height": 2.5, "Elevation": 13.5, "Grid_ID": 52.0, "LocationClass": "Urban Traffic", "LAQM_Locationclass": "Roadside", "Survey": "Roadside (DT)", "RouteID": null, "RouteSequenceID": null, "Description": "", "DateStart": null, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": "", "obstruction_m": null, "obstruction_lt": "No", "inlet_flow_clear": "No", "junction_m": null, "x": -2.534937419314335, "y": 51.44686157275239, "x_normalized": 0.64610652790402945, "y_normalized": 0.2604651853675648 }, "geometry": { "type": "Point", "coordinates": [ -2.534937419314335, 51.44686157275239 ] } },
# { "type": "Feature", "properties": { "OBJECTID":
.0, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": null, "obstruction_m": null, "obstruction_lt": null, "inlet_flow_clear": null, "junction_m": null, "x": -2.525999421344697, "y": 51.454194265406947, "x_normalized": 0.6649186618489491, "y_normalized": 0.2922456687934698 }, "geometry": { "type": "Point", "coordinates": [ -2.525999421344697, 51.454194265406947 ] } },
# { "type": "Feature", "properties": { "OBJECTID": 700, "siteNo": null, "location": "Barton Hill Academy", "SiteID": 711, "Easting": 360877, "Northing": 172939, "Current_": "Yes", "pollutants": "NO2", "InstrumentID": 1, "Exposure": "No", "tube_kerb": 1.0, "rec_kerb": 0.0, "comments": null, "AQMA": "Yes", "Detailed_Location": null, "Tube_Height": 2.3, "Elevation": null, "Grid_ID": null, "LocationClass": null, "LAQM_Locationclass": "Roadside", "Survey": null, "RouteID": null, "RouteSequenceID": null, "Description": null, "DateStart": 1722384000000.0, "DateEnd": null, "Colocated": null, "Duplicate_Triplicate": null, "obstruction_m": null, "obstruction_lt": null, "inlet_flow_clear": null, "junction_m": null, "x": -2.5644398053427331, "y": 51.454069770697508, "x_normalized": 0.58401176803204802, "y_normalized": 0.29170609864695507 }, "geometry": { "type": "Point", "coordinates": [ -2.564439805342733, 51.454069770697508 ] } }
# ]
# }

# %%
dataframe_df = gpd.read_file("C:/Users/aldom/Documents/Data_Enginnering/Final_ETL_Portfolio_Submission/api_data.geojson", encoding="ISO-8859-1")

# %% [markdown]
# normalizing geometry with 0,1 vaules

# %%
from sklearn.preprocessing import MinMaxScaler

# Extracting the coordinates

dataframe_df['x'] = dataframe_df.geometry.x
dataframe_df['y'] = dataframe_df.geometry.y

# Normalizing 

normalized_scale = MinMaxScaler()
dataframe_df[['x_normalized', 'y_normalized']] = normalized_scale.fit_transform(dataframe_df[['x', 'y']])


print(dataframe_df[['geometry', 'x_normalized', 'y_normalized']].head())
# Out:
#                     geometry  x_normalized  y_normalized
# 0  POINT (-2.62775 51.40775)      0.450763      0.090933
# 1  POINT (-2.59681 51.45456)      0.515873      0.293816
# 2  POINT (-2.61399 51.46921)      0.479713      0.357306
# 3  POINT (-2.57833 51.44421)      0.554769      0.248973
# 4  POINT (-2.59529 51.44281)      0.519071      0.242914

# %%
# Check values

check_x = dataframe_df['x_normalized'].between(0, 1).all()
check_y = dataframe_df['y_normalized'].between(0, 1).all()

print(f"x is normalized: {check_x}")
print(f"y is normalized: {check_y}")
# Out:
# x is normalized: True
# y is normalized: True

# %% [markdown]
# Updating the geometry column with the normalized values

# %%
from shapely.geometry import Point

# Column update

dataframe_df['geometry'] = dataframe_df.apply(lambda row: Point(row['x_normalized'], row['y_normalized']), axis=1)

print(dataframe_df[['geometry', 'x_normalized', 'y_normalized']].head())
# Out:
#                   geometry  x_normalized  y_normalized
# 0  POINT (0.45076 0.09093)      0.450763      0.090933
# 1  POINT (0.51587 0.29382)      0.515873      0.293816
# 2  POINT (0.47971 0.35731)      0.479713      0.357306
# 3  POINT (0.55477 0.24897)      0.554769      0.248973
# 4  POINT (0.51907 0.24291)      0.519071      0.242914

# %% [markdown]
# SiteID, location, siteNo, siteNo, x_normalized, y_normalized, geometry

# %%
null_counts = dataframe_df.isnull().sum()
print(null_counts)
# Out:
# OBJECTID                  0
# siteNo                   11
# location                  0
# SiteID                    0
# Easting                   0
# Northing                  0
# Current_                  0
# pollutants                0
# InstrumentID              0
# Exposure                  0
# tube_kerb               378
# rec_kerb                379
# comments                 11
# AQMA                      0
# Detailed_Location        11
# Tube_Height             368
# Elevation                13
# Grid_ID                 104
# LocationClass            11
# LAQM_Locationclass        0
# Survey                   10
# RouteID                 700
# RouteSequenceID         607
# Description              11
# DateStart               533
# DateEnd                 690
# Colocated               692
# Duplicate_Triplicate     11
# obstruction_m           499
# obstruction_lt           11
# inlet_flow_clear         11
# junction_m              499
# x                         0
# y                         0
# x_normalized              0
# y_normalized              0
# geometry                  0
# dtype: int64

# %% [markdown]
# fitting the transforemd data

# %%
# fit the data in latitude (normalized)

dataframe_df['Latitude (normalized)'] = list(zip(dataframe_df['x_normalized'], dataframe_df['y_normalized']))
print(dataframe_df[['x_normalized', 'y_normalized', 'Latitude (normalized)']].head())
# Out:
#    x_normalized  y_normalized                       Latitude (normalized)
# 0      0.450763      0.090933  (0.45076298550013316, 0.09093303826767851)
# 1      0.515873      0.293816    (0.5158727171676434, 0.2938159127984079)
# 2      0.479713      0.357306     (0.479712873484198, 0.3573055285403086)
# 3      0.554769      0.248973    (0.5547692739533074, 0.2489726016785312)
# 4      0.519071      0.242914    (0.5190709212978044, 0.2429141946354605)

# %%
# select the relevant columns
dataframe_df = dataframe_df[['SiteID', 'location', 'siteNo','Latitude (normalized)']]
print(dataframe_df.head())
# Out:
#    SiteID           location siteNo  \
# 0       1   Withywood School      1
# 1       2     Colston Avenue     B1
# 2       3      Blackboy Hill    B10
# 3       4        Three Lamps    B11
# 4       5  Bedminster Parade    B12
#
#                         Latitude (normalized)
# 0  (0.45076298550013316, 0.09093303826767851)
# 1    (0.5158727171676434, 0.2938159127984079)
# 2     (0.479712873484198, 0.3573055285403086)
# 3    (0.5547692739533074, 0.2489726016785312)
# 4    (0.5190709212978044, 0.2429141946354605)

# %%
# rename the columns as asked in the exercise
dataframe_df.rename(columns={'SiteID': 'ID', 'siteNo': 'Location Type'}, inplace=True)
print(dataframe_df.head())
# Out:
#    ID           location Location Type  \
# 0   1   Withywood School             1
# 1   2     Colston Avenue            B1
# 2   3      Blackboy Hill           B10
# 3   4        Three Lamps           B11
# 4   5  Bedminster Parade           B12
#
#                         Latitude (normalized)
# 0  (0.45076298550013316, 0.09093303826767851)
# 1    (0.5158727171676434, 0.2938159127984079)
# 2     (0.479712873484198, 0.3573055285403086)
# 3    (0.5547692739533074, 0.2489726016785312)
# 4    (0.5190709212978044, 0.2429141946354605)

# %%
print(dataframe_df.dtypes)
# Out:
# ID                        int32
# location                 object
# Location Type            object
# Latitude (normalized)    object
# dtype: object

# %%
final_data = dataframe_df.copy()
print(final_data.head())
# Out:
#    ID           location Location Type  \
# 0   1   Withywood School             1
# 1   2     Colston Avenue            B1
# 2   3      Blackboy Hill           B10
# 3   4        Three Lamps           B11
# 4   5  Bedminster Parade           B12
#
#                         Latitude (normalized)
# 0  (0.45076298550013316, 0.09093303826767851)
# 1    (0.5158727171676434, 0.2938159127984079)
# 2     (0.479712873484198, 0.3573055285403086)
# 3    (0.5547692739533074, 0.2489726016785312)
# 4    (0.5190709212978044, 0.2429141946354605)

# %%
#save the final data to a CSV file
final_data.to_csv("C:\\Users\\aldom\\Documents\\Data_Enginnering\\Final_ETL_Portfolio_Submission\\final_data.csv", index=False)

# %%
import os
import sys

os.environ["JAVA_HOME"] = "JDK 8"
os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# %%
# Create a Spark session
Spark_Session = SparkSession.builder \
    .appName("AirQualityBristol") \
    .getOrCreate()

print(Spark_Session)
# Out:
# <pyspark.sql.session.SparkSession object at 0x000001ACFDCB8C10>

# %%
# Load the final_data.csv into a Spark DataFrame
Air_Quality_Bristol_df = Spark_Session.read.csv("C:\\Users\\aldom\\Documents\\Data_Enginnering\\Final_ETL_Portfolio_Submission\\final_data.csv", header=True, inferSchema=True)

Air_Quality_Bristol_df.printSchema()
Air_Quality_Bristol_df.show(5)
# Out:
# root
#  |-- ID: integer (nullable = true)
#  |-- location: string (nullable = true)
#  |-- Location Type: string (nullable = true)
#  |-- Latitude (normalized): string (nullable = true)
#
# +---+-----------------+-------------+---------------------+
# | ID|         location|Location Type|Latitude (normalized)|
# +---+-----------------+-------------+---------------------+
# |  1| Withywood School|            1| (0.45076298550013...|
# |  2|   Colston Avenue|           B1| (0.51587271716764...|
# |  3|    Blackboy Hill|          B10| (0.47971287348419...|
# |  4|      Three Lamps|          B11| (0.55476927395330...|
# |  5|Bedminster Parade|          B12| (0.51907092129780...|
# +---+-----------------+-------------+---------------------+
# only showing top 5 rows

# %%
#create the new spark session
sql_spark = SparkSession.builder.appName("ETLAssignment").getOrCreate()

# %%
# load the CSV file into a DataFrame in PostgreSQL

pg_url = "jdbc:postgresql://localhost:5432/ETLAssignment"
my_account = {
    "user": "postgres",
    "password": "050887",
    "driver": "org.postgresql.Driver"
}

# Write the transformed data to the database

Air_Quality_Bristol_df.write.jdbc(
    url=pg_url, \
    table="AirQualityBristol",
    mode="overwrite",
    properties=my_account
)

# %% [markdown]
# Visualizing data

# %%
import matplotlib.pyplot as plt

# Convert Spark DataFrame to Pandas DataFrame
pandas_df = Air_Quality_Bristol_df.toPandas()

# Extract x and y coordinates from 'Latitude (normalized)'
pandas_df['x_normalized'] = pandas_df['Latitude (normalized)'].apply(lambda x: float(x.strip('()').split(',')[0]))
pandas_df['y_normalized'] = pandas_df['Latitude (normalized)'].apply(lambda x: float(x.strip('()').split(',')[1]))

# Plot the data
plt.figure(figsize=(10, 6))
plt.scatter(pandas_df['x_normalized'], pandas_df['y_normalized'], alpha=0.6, edgecolor='k')
plt.title('Air Quality Bristol - Box Monitor City Locations')
plt.xlabel('x - Longitude (normalized)')
plt.ylabel('y - Latitude (normalized)')
plt.xlim(0, 1)
plt.grid(True)
plt.show()

# %% [markdown]
# Counting Total number of locations

# %%
total_locations = Air_Quality_Bristol_df.select("location").distinct().count()
print(f"The Total number of locations is: {total_locations}")
print("This is the number of Box Monitor Around Bristol City")
# Out:
# The Total number of locations is: 674
# This is the number of Box Monitor Around Bristol City
